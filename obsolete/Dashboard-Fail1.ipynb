# %%
# !pip install dash==0.32.2  # The core dash backend
# !pip install dash-html-components==0.13.2  # HTML components
# !pip install dash-core-components==0.40.3  # Supercharged components
# !pip install dash-table==3.1.11  # Interactive DataTable component (new!)
# Out:
# Requirement already satisfied: dash==0.32.2 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (0.32.2)
# Requirement already satisfied: dash-renderer in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from dash==0.32.2) (0.16.1)
# Requirement already satisfied: Flask>=0.12 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from dash==0.32.2) (1.0.2)
# Requirement already satisfied: flask-compress in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from dash==0.32.2) (1.4.0)
# Requirement already satisfied: plotly in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from dash==0.32.2) (3.4.2)
# Requirement already satisfied: Werkzeug>=0.14 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from Flask>=0.12->dash==0.32.2) (0.14.1)
# Requirement already satisfied: click>=5.1 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from Flask>=0.12->dash==0.32.2) (6.7)
# Requirement already satisfied: itsdangerous>=0.24 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from Flask>=0.12->dash==0.32.2) (0.24)
# Requirement already satisfied: Jinja2>=2.10 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from Flask>=0.12->dash==0.32.2) (2.10)
# Requirement already satisfied: decorator>=4.0.6 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from plotly->dash==0.32.2) (4.3.0)
# Requirement already satisfied: six in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from plotly->dash==0.32.2) (1.11.0)
# Requirement already satisfied: nbformat>=4.2 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from plotly->dash==0.32.2) (4.4.0)
# Requirement already satisfied: pytz in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from plotly->dash==0.32.2) (2018.7)
# Requirement already satisfied: requests in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from plotly->dash==0.32.2) (2.20.1)
# Requirement already satisfied: retrying>=1.3.3 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from plotly->dash==0.32.2) (1.3.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from Jinja2>=2.10->Flask>=0.12->dash==0.32.2) (1.1.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from nbformat>=4.2->plotly->dash==0.32.2) (2.6.0)
# Requirement already satisfied: traitlets>=4.1 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from nbformat>=4.2->plotly->dash==0.32.2) (4.3.2)
# Requirement already satisfied: ipython-genutils in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from nbformat>=4.2->plotly->dash==0.32.2) (0.2.0)
# Requirement already satisfied: jupyter-core in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from nbformat>=4.2->plotly->dash==0.32.2) (4.4.0)
# Requirement already satisfied: idna<2.8,>=2.5 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from requests->plotly->dash==0.32.2) (2.7)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from requests->plotly->dash==0.32.2) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from requests->plotly->dash==0.32.2) (1.23)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from requests->plotly->dash==0.32.2) (2018.10.15)
# Requirement already satisfied: functools32 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly->dash==0.32.2) (3.2.3.post2)
# Requirement already satisfied: enum34 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from traitlets>=4.1->nbformat>=4.2->plotly->dash==0.32.2) (1.1.6)
# Requirement already satisfied: dash-html-components==0.13.2 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (0.13.2)
# Requirement already satisfied: dash in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from dash-html-components==0.13.2) (0.32.2)
# Requirement already satisfied: dash-renderer in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from dash->dash-html-components==0.13.2) (0.16.1)
# Requirement already satisfied: Flask>=0.12 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from dash->dash-html-components==0.13.2) (1.0.2)
# Requirement already satisfied: flask-compress in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from dash->dash-html-components==0.13.2) (1.4.0)
# Requirement already satisfied: plotly in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from dash->dash-html-components==0.13.2) (3.4.2)
# Requirement already satisfied: Werkzeug>=0.14 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from Flask>=0.12->dash->dash-html-components==0.13.2) (0.14.1)
# Requirement already satisfied: click>=5.1 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from Flask>=0.12->dash->dash-html-components==0.13.2) (6.7)
# Requirement already satisfied: itsdangerous>=0.24 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from Flask>=0.12->dash->dash-html-components==0.13.2) (0.24)
# Requirement already satisfied: Jinja2>=2.10 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from Flask>=0.12->dash->dash-html-components==0.13.2) (2.10)
# Requirement already satisfied: decorator>=4.0.6 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from plotly->dash->dash-html-components==0.13.2) (4.3.0)
# Requirement already satisfied: six in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from plotly->dash->dash-html-components==0.13.2) (1.11.0)
# Requirement already satisfied: nbformat>=4.2 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from plotly->dash->dash-html-components==0.13.2) (4.4.0)
# Requirement already satisfied: pytz in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from plotly->dash->dash-html-components==0.13.2) (2018.7)
# Requirement already satisfied: requests in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from plotly->dash->dash-html-components==0.13.2) (2.20.1)
# Requirement already satisfied: retrying>=1.3.3 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from plotly->dash->dash-html-components==0.13.2) (1.3.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from Jinja2>=2.10->Flask>=0.12->dash->dash-html-components==0.13.2) (1.1.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from nbformat>=4.2->plotly->dash->dash-html-components==0.13.2) (2.6.0)
# Requirement already satisfied: traitlets>=4.1 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from nbformat>=4.2->plotly->dash->dash-html-components==0.13.2) (4.3.2)
# Requirement already satisfied: ipython-genutils in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from nbformat>=4.2->plotly->dash->dash-html-components==0.13.2) (0.2.0)
# Requirement already satisfied: jupyter-core in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from nbformat>=4.2->plotly->dash->dash-html-components==0.13.2) (4.4.0)
# Requirement already satisfied: idna<2.8,>=2.5 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from requests->plotly->dash->dash-html-components==0.13.2) (2.7)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from requests->plotly->dash->dash-html-components==0.13.2) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from requests->plotly->dash->dash-html-components==0.13.2) (1.23)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from requests->plotly->dash->dash-html-components==0.13.2) (2018.10.15)
# Requirement already satisfied: functools32 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly->dash->dash-html-components==0.13.2) (3.2.3.post2)
# Requirement already satisfied: enum34 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from traitlets>=4.1->nbformat>=4.2->plotly->dash->dash-html-components==0.13.2) (1.1.6)
# Requirement already satisfied: dash-core-components==0.40.3 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (0.40.3)
# Requirement already satisfied: dash in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from dash-core-components==0.40.3) (0.32.2)
# Requirement already satisfied: dash-renderer in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from dash->dash-core-components==0.40.3) (0.16.1)
# Requirement already satisfied: Flask>=0.12 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from dash->dash-core-components==0.40.3) (1.0.2)
# Requirement already satisfied: flask-compress in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from dash->dash-core-components==0.40.3) (1.4.0)
# Requirement already satisfied: plotly in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from dash->dash-core-components==0.40.3) (3.4.2)
# Requirement already satisfied: Werkzeug>=0.14 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from Flask>=0.12->dash->dash-core-components==0.40.3) (0.14.1)
# Requirement already satisfied: click>=5.1 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from Flask>=0.12->dash->dash-core-components==0.40.3) (6.7)
# Requirement already satisfied: itsdangerous>=0.24 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from Flask>=0.12->dash->dash-core-components==0.40.3) (0.24)
# Requirement already satisfied: Jinja2>=2.10 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from Flask>=0.12->dash->dash-core-components==0.40.3) (2.10)
# Requirement already satisfied: decorator>=4.0.6 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from plotly->dash->dash-core-components==0.40.3) (4.3.0)
# Requirement already satisfied: six in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from plotly->dash->dash-core-components==0.40.3) (1.11.0)
# Requirement already satisfied: nbformat>=4.2 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from plotly->dash->dash-core-components==0.40.3) (4.4.0)
# Requirement already satisfied: pytz in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from plotly->dash->dash-core-components==0.40.3) (2018.7)
# Requirement already satisfied: requests in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from plotly->dash->dash-core-components==0.40.3) (2.20.1)
# Requirement already satisfied: retrying>=1.3.3 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from plotly->dash->dash-core-components==0.40.3) (1.3.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from Jinja2>=2.10->Flask>=0.12->dash->dash-core-components==0.40.3) (1.1.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from nbformat>=4.2->plotly->dash->dash-core-components==0.40.3) (2.6.0)
# Requirement already satisfied: traitlets>=4.1 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from nbformat>=4.2->plotly->dash->dash-core-components==0.40.3) (4.3.2)
# Requirement already satisfied: ipython-genutils in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from nbformat>=4.2->plotly->dash->dash-core-components==0.40.3) (0.2.0)
# Requirement already satisfied: jupyter-core in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from nbformat>=4.2->plotly->dash->dash-core-components==0.40.3) (4.4.0)
# Requirement already satisfied: idna<2.8,>=2.5 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from requests->plotly->dash->dash-core-components==0.40.3) (2.7)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from requests->plotly->dash->dash-core-components==0.40.3) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from requests->plotly->dash->dash-core-components==0.40.3) (1.23)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from requests->plotly->dash->dash-core-components==0.40.3) (2018.10.15)
# Requirement already satisfied: functools32 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly->dash->dash-core-components==0.40.3) (3.2.3.post2)
# Requirement already satisfied: enum34 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from traitlets>=4.1->nbformat>=4.2->plotly->dash->dash-core-components==0.40.3) (1.1.6)
# Requirement already satisfied: dash-table==3.1.11 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (3.1.11)
# Requirement already satisfied: dash in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from dash-table==3.1.11) (0.32.2)
# Requirement already satisfied: dash-renderer in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from dash->dash-table==3.1.11) (0.16.1)
# Requirement already satisfied: Flask>=0.12 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from dash->dash-table==3.1.11) (1.0.2)
# Requirement already satisfied: flask-compress in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from dash->dash-table==3.1.11) (1.4.0)
# Requirement already satisfied: plotly in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from dash->dash-table==3.1.11) (3.4.2)
# Requirement already satisfied: Werkzeug>=0.14 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from Flask>=0.12->dash->dash-table==3.1.11) (0.14.1)
# Requirement already satisfied: click>=5.1 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from Flask>=0.12->dash->dash-table==3.1.11) (6.7)
# Requirement already satisfied: itsdangerous>=0.24 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from Flask>=0.12->dash->dash-table==3.1.11) (0.24)
# Requirement already satisfied: Jinja2>=2.10 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from Flask>=0.12->dash->dash-table==3.1.11) (2.10)
# Requirement already satisfied: decorator>=4.0.6 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from plotly->dash->dash-table==3.1.11) (4.3.0)
# Requirement already satisfied: six in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from plotly->dash->dash-table==3.1.11) (1.11.0)
# Requirement already satisfied: nbformat>=4.2 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from plotly->dash->dash-table==3.1.11) (4.4.0)
# Requirement already satisfied: pytz in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from plotly->dash->dash-table==3.1.11) (2018.7)
# Requirement already satisfied: requests in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from plotly->dash->dash-table==3.1.11) (2.20.1)
# Requirement already satisfied: retrying>=1.3.3 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from plotly->dash->dash-table==3.1.11) (1.3.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from Jinja2>=2.10->Flask>=0.12->dash->dash-table==3.1.11) (1.1.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from nbformat>=4.2->plotly->dash->dash-table==3.1.11) (2.6.0)
# Requirement already satisfied: traitlets>=4.1 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from nbformat>=4.2->plotly->dash->dash-table==3.1.11) (4.3.2)
# Requirement already satisfied: ipython-genutils in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from nbformat>=4.2->plotly->dash->dash-table==3.1.11) (0.2.0)
# Requirement already satisfied: jupyter-core in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from nbformat>=4.2->plotly->dash->dash-table==3.1.11) (4.4.0)
# Requirement already satisfied: idna<2.8,>=2.5 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from requests->plotly->dash->dash-table==3.1.11) (2.7)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from requests->plotly->dash->dash-table==3.1.11) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from requests->plotly->dash->dash-table==3.1.11) (1.23)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from requests->plotly->dash->dash-table==3.1.11) (2018.10.15)
# Requirement already satisfied: functools32 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly->dash->dash-table==3.1.11) (3.2.3.post2)
# Requirement already satisfied: enum34 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from traitlets>=4.1->nbformat>=4.2->plotly->dash->dash-table==3.1.11) (1.1.6)

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output

external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']

app = dash.Dash(__name__, external_stylesheets=external_stylesheets)

app.layout = html.Div([
    dcc.Input(id='my-id', value='initial value', type='text'),
    html.Div(id='my-div')
])


@app.callback(
    Output(component_id='my-div', component_property='children'),
    [Input(component_id='my-id', component_property='value')]
)
def update_output_div(input_value):
    return 'You\'ve entered "{}"'.format(input_value)


#if __name__ == '__main__':
#    app.run_server(debug=True)
show_app('app')
# Out:
# <iframe src="http://localhost:9999" width=700 height=350></iframe>
# AttributeErrorTraceback (most recent call last)
# <ipython-input-3-6186c5c8e457> in <module>()
#      24 #if __name__ == '__main__':
#      25 #    app.run_server(debug=True)
# ---> 26 show_app('app')
#
# <ipython-input-2-52b118310f57> in show_app(app, port, width, height, offline, style, **dash_flask_kwargs)
#      22     display.display_html(iframe, raw=True)
#      23     if offline:
# ---> 24         app.css.config.serve_locally = True
#      25         app.scripts.config.serve_locally = True
#      26     if style:
#
# AttributeError: 'str' object has no attribute 'css'

# %%
from jupyter_plotly_dash import JupyterDash

import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output

app = JupyterDash('SimpleExample')

app.layout = html.Div([
    dcc.RadioItems(
        id='dropdown-color',
        options=[{'label': c, 'value': c.lower()}
                 for c in ['Red', 'Green', 'Blue']],
        value='red'
    ),
    html.Div(id='output-color'),
    dcc.RadioItems(
        id='dropdown-size',
        options=[{'label': i, 'value': j}
                 for i, j in [('L','large'), ('M','medium'), ('S','small')]],
        value='medium'
    ),
    html.Div(id='output-size')

])

@app.callback(
    dash.dependencies.Output('output-color', 'children'),
    [dash.dependencies.Input('dropdown-color', 'value')])
def callback_color(dropdown_value):
    return "The selected color is %s." % dropdown_value

@app.callback(
    dash.dependencies.Output('output-size', 'children'),
    [dash.dependencies.Input('dropdown-color', 'value'),
     dash.dependencies.Input('dropdown-size', 'value')])
def callback_size(dropdown_color, dropdown_size):
    return "The chosen T-shirt is a %s %s one." %(dropdown_size,
                                                  dropdown_color)

app

# %%
# %run -i '../libs/dashtest.py'
# Out:
# Running on http://127.0.0.1:8050/
# Debugger PIN: 762-375-297
#  * Serving Flask app "dashtest" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: on
