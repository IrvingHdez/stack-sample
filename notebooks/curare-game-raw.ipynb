# %% [markdown]
# # Excecute every cell independently from top to bottom

# %%
# Data collection is presented maybe in another notebook

# %%
# Tasks

# %%
import pandas as pd

# %% [markdown]
# # Raw Stack overflow data dump from January 1rst to January 4th 2018
#
# ## January 1rst 2018
# ### Badges

# %%
relA1_df = pd.read_csv("../releases/jan-01-02_2018/BADGES_jan-01-02_2018.csv")
print(relA1_df.to_string())
# Out:
#            Id   UserId               Name                 Date  Class  TagBased
# 0    26412268  9159465           Informed  2018-01-01 00:00:58      3     False
# 1    26412269   439040        Good Answer  2018-01-01 00:02:09      2     False
# 2    26412270  1511332        Good Answer  2018-01-01 00:02:09      2     False
# 3    26412271  1591934        Good Answer  2018-01-01 00:02:09      2     False
# 4    26412272  2538939        Good Answer  2018-01-01 00:02:09      2     False
# 5    26412273  7897125            Curious  2018-01-01 00:02:09      3     False
# 6    26412274  6629915            Curious  2018-01-01 00:02:09      3     False
# 7    26412275  1199051            Curious  2018-01-01 00:02:09      3     False
# 8    26412276  1223387            Curious  2018-01-01 00:02:09      3     False
# 9    26412277   812504            Curious  2018-01-01 00:02:09      3     False
# 10   26412278  1615720            Curious  2018-01-01 00:02:09      3     False
# ...

# %%
relA1_df.describe(include='all')
# Out:
#                   Id        UserId    Name                 Date       Class  \
# count   2.000000e+02  2.000000e+02     200                  200  200.000000
# unique           NaN           NaN      37                   32         NaN
# top              NaN           NaN  Editor  2018-01-01 00:02:09         NaN
# freq             NaN           NaN      16                   45         NaN
# mean    2.641237e+07  5.038209e+06     NaN                  NaN    2.655000
# std     6.113607e+01  3.199776e+06     NaN                  NaN    0.598134
# min     2.641227e+07  8.251100e+04     NaN                  NaN    1.000000
# 25%     2.641232e+07  1.940383e+06     NaN                  NaN    2.000000
# 50%     2.641237e+07  4.922868e+06     NaN                  NaN    3.000000
# 75%     2.641242e+07  8.568773e+06     NaN                  NaN    3.000000
# max     2.641253e+07  9.159531e+06     NaN                  NaN    3.000000
#
#        TagBased
# count       200
# unique        1
# ...

# %% [markdown]
# ### Comments

# %%
relA2_df = pd.read_csv("../releases/jan-01-02_2018/COMMENTS_jan-01-02_2018.csv")
print(relA2_df.to_string())
# Out:
#            Id    PostId  Score                                               Text         CreationDate UserDisplayName     UserId
# 0    83064109  48046364      0  Yes, I;ve done that too.  I think I know how t...  2018-01-01 00:00:06             NaN  8754098.0
# 1    83064110  48046356      1  Your numberOfMilliSecondsUntilMidnight have on...  2018-01-01 00:00:16             NaN  1187415.0
# 2    83064111  48046185      0  The result is fine. The graph comes out great ...  2018-01-01 00:00:44             NaN  9116172.0
# 3    83064113  48045799      0  why do you convert fetchall into `str()` ? Wit...  2018-01-01 00:00:59             NaN  1832058.0
# 4    83064114  48038560      0  This sounds like above my skill level. Maybe a...  2018-01-01 00:01:04             NaN   930993.0
# 5    83064116  48046178      0  Use `ConvertTo-Csv` and replace 3 consecutive ...  2018-01-01 00:01:30             NaN  1630171.0
# ...

# %%
relA2_df.describe(include='all')
# Out:
#                   Id        PostId       Score  \
# count   9.880000e+02  9.880000e+02  988.000000
# unique           NaN           NaN         NaN
# top              NaN           NaN         NaN
# freq             NaN           NaN         NaN
# mean    8.306486e+07  4.596131e+07    0.244939
# std     4.347223e+02  7.866254e+06    0.717931
# min     8.306411e+07  1.120250e+05    0.000000
# 25%     8.306450e+07  4.804081e+07    0.000000
# 50%     8.306485e+07  4.804639e+07    0.000000
# 75%     8.306525e+07  4.804662e+07    0.000000
# max     8.306561e+07  4.804699e+07    8.000000
#
#                                                      Text  \
# count                                                 988
# unique                                                978
# top     Stack Overflow is a site for programming and d...
# freq                                                    8
# mean                                                  NaN
# ...

# %% [markdown]
# ### Posts

# %%
relA3_df = pd.read_csv("../releases/jan-01-02_2018/POSTS_jan-01-02_2018.csv")
print(relA3_df.to_string())
# Out:
#           Id  PostTypeId  AcceptedAnswerId    ParentId         CreationDate         DeletionDate  Score  ViewCount                                               Body  OwnerUserId OwnerDisplayName  LastEditorUserId  LastEditorDisplayName         LastEditDate     LastActivityDate                                              Title                                               Tags  AnswerCount  CommentCount  FavoriteCount  ClosedDate  CommunityOwnedDate
# 0   48046378         1.0               NaN         NaN  2018-01-01 00:00:29                  NaN    0.0      112.0  <p>Calling a <em>dll</em> from Python using <e...    8276973.0              NaN          236247.0                    NaN  2018-01-01 03:16:54  2018-01-03 08:21:23    Python ctypes: how to pass ctypes array to DLL?                                   <python><ctypes>          2.0           0.0            NaN         NaN                 NaN
# ...

# %%
relA3_df.describe(include='all')
# Out:
#               Id  PostTypeId  AcceptedAnswerId      ParentId  \
# count         47   46.000000      8.000000e+00  2.500000e+01
# unique        47         NaN               NaN           NaN
# top     48046378         NaN               NaN           NaN
# freq           1         NaN               NaN           NaN
# mean         NaN    1.543478      4.807512e+07  4.803257e+07
# std          NaN    0.503610      7.955717e+04  6.425668e+04
# min          NaN    1.000000      4.804643e+07  4.772433e+07
# 25%          NaN    1.000000      4.804646e+07  4.804614e+07
# 50%          NaN    2.000000      4.804653e+07  4.804634e+07
# 75%          NaN    2.000000      4.804765e+07  4.804636e+07
# max          NaN    2.000000      4.827200e+07  4.804642e+07
#
#                CreationDate         DeletionDate      Score    ViewCount  \
# count                    46                    1  46.000000    21.000000
# unique                   46                    1        NaN          NaN
# ...

# %% [markdown]
# ### Users

# %%
relA4_df = pd.read_csv("../releases/jan-01-02_2018/USERS_jan-01-02_2018.csv")
print(relA4_df.to_string())
# Out:
#           Id  Reputation         CreationDate                    DisplayName       LastAccessDate                                         WebsiteUrl                                           Location                                            AboutMe  Views  UpVotes  DownVotes                                    ProfileImageUrl  EmailHash  AccountId
# 0    9159469           1  2018-01-01 00:00:47                            wil  2018-03-30 22:12:13                                                NaN                                                NaN                                                NaN      0        0          0  https://www.gravatar.com/avatar/5f1d775e49b29f...        NaN   12594064
# ...

# %%
relA4_df.describe(include='all')
# Out:
#                   Id  Reputation         CreationDate DisplayName  \
# count   9.210000e+02  921.000000                  921         921
# unique           NaN         NaN                  910         920
# top              NaN         NaN  2018-01-01 05:06:37      Andrew
# freq             NaN         NaN                    2           2
# mean    9.160065e+06    3.804560                  NaN         NaN
# std     4.081911e+02   14.692087                  NaN         NaN
# min     9.159469e+06    1.000000                  NaN         NaN
# 25%     9.159708e+06    1.000000                  NaN         NaN
# 50%     9.160087e+06    1.000000                  NaN         NaN
# 75%     9.160325e+06    1.000000                  NaN         NaN
# max     9.161005e+06  178.000000                  NaN         NaN
#
#              LastAccessDate              WebsiteUrl Location  \
# count                   921                      27      346
# ...

# %% [markdown]
# ### Votes

# %%
relA5_df = pd.read_csv("../releases/jan-01-02_2018/VOTES_jan-01-02_2018.csv")
print(relA5_df.to_string())
# Out:
#              Id    PostId  VoteTypeId     UserId         CreationDate  BountyAmount
# 0     154211782  48046304           3        NaN  2018-01-01 00:00:00           NaN
# 1     154211783  48046293           2        NaN  2018-01-01 00:00:00           NaN
# 2     154211785  48046339           2        NaN  2018-01-01 00:00:00           NaN
# 3     154211787  12934468           2        NaN  2018-01-01 00:00:00           NaN
# 4     154211788   4088524           2        NaN  2018-01-01 00:00:00           NaN
# 5     154211789  48046371          10        NaN  2018-01-01 00:00:00           NaN
# 6     154211790  48046318           2        NaN  2018-01-01 00:00:00           NaN
# 7     154211791  48046334          10        NaN  2018-01-01 00:00:00           NaN
# 8     154211792  36507481           2        NaN  2018-01-01 00:00:00           NaN
# 9     154211793  48044734          16        NaN  2018-01-01 00:00:00           NaN
# ...

# %%
relA5_df.describe(include='all')
# Out:
#                   Id        PostId   VoteTypeId        UserId  \
# count   1.023000e+03  1.023000e+03  1023.000000  7.400000e+01
# unique           NaN           NaN          NaN           NaN
# top              NaN           NaN          NaN           NaN
# freq             NaN           NaN          NaN           NaN
# mean    1.542123e+08  3.300841e+07     3.020528  5.058675e+06
# std     3.206166e+02  1.763383e+07     2.632510  3.272631e+06
# min     1.542118e+08  1.540000e+02     1.000000  4.485200e+04
# 25%     1.542121e+08  1.526348e+07     2.000000  1.984560e+06
# 50%     1.542123e+08  4.402906e+07     2.000000  4.789452e+06
# 75%     1.542126e+08  4.804588e+07     3.000000  8.754545e+06
# max     1.542129e+08  4.804661e+07    16.000000  9.159420e+06
#
#                CreationDate  BountyAmount
# count                  1023           0.0
# unique                    1           NaN
# top     2018-01-01 00:00:00           NaN
# freq                   1023           NaN
# ...
