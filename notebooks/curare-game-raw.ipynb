# %% [markdown]
# # Excecute every cell independently from top to bottom

# %%
# Data collection is presented maybe in another notebook

# %%
# Tasks

# %%
import pandas as pd

# %% [markdown]
# # Raw Stack overflow data dump from January 1rst to January 4th 2018
#
# ## January 1rst 2018
# ### Badges

# %%
relA1_df = pd.read_csv("../releases/jan-01-02_2018/BADGES_jan-01-02_2018.csv")
print(relA1_df.to_string())
# Out:
#            Id   UserId               Name                 Date  Class  TagBased
# 0    26412268  9159465           Informed  2018-01-01 00:00:58      3     False
# 1    26412269   439040        Good Answer  2018-01-01 00:02:09      2     False
# 2    26412270  1511332        Good Answer  2018-01-01 00:02:09      2     False
# 3    26412271  1591934        Good Answer  2018-01-01 00:02:09      2     False
# 4    26412272  2538939        Good Answer  2018-01-01 00:02:09      2     False
# 5    26412273  7897125            Curious  2018-01-01 00:02:09      3     False
# 6    26412274  6629915            Curious  2018-01-01 00:02:09      3     False
# 7    26412275  1199051            Curious  2018-01-01 00:02:09      3     False
# 8    26412276  1223387            Curious  2018-01-01 00:02:09      3     False
# 9    26412277   812504            Curious  2018-01-01 00:02:09      3     False
# 10   26412278  1615720            Curious  2018-01-01 00:02:09      3     False
# ...

# %%
relA1_df.describe(include='all')
# Out:
#                   Id        UserId    Name                 Date       Class  \
# count   2.000000e+02  2.000000e+02     200                  200  200.000000
# unique           NaN           NaN      37                   32         NaN
# top              NaN           NaN  Editor  2018-01-01 00:02:09         NaN
# freq             NaN           NaN      16                   45         NaN
# mean    2.641237e+07  5.038209e+06     NaN                  NaN    2.655000
# std     6.113607e+01  3.199776e+06     NaN                  NaN    0.598134
# min     2.641227e+07  8.251100e+04     NaN                  NaN    1.000000
# 25%     2.641232e+07  1.940383e+06     NaN                  NaN    2.000000
# 50%     2.641237e+07  4.922868e+06     NaN                  NaN    3.000000
# 75%     2.641242e+07  8.568773e+06     NaN                  NaN    3.000000
# max     2.641253e+07  9.159531e+06     NaN                  NaN    3.000000
#
#        TagBased
# count       200
# unique        1
# ...

# %% [markdown]
# ### Comments

# %%
relA2_df = pd.read_csv("../releases/jan-01-02_2018/COMMENTS_jan-01-02_2018.csv")
print(relA2_df.to_string())
# Out:
#            Id    PostId  Score                                               Text         CreationDate UserDisplayName     UserId
# 0    83064109  48046364      0  Yes, I;ve done that too.  I think I know how t...  2018-01-01 00:00:06             NaN  8754098.0
# 1    83064110  48046356      1  Your numberOfMilliSecondsUntilMidnight have on...  2018-01-01 00:00:16             NaN  1187415.0
# 2    83064111  48046185      0  The result is fine. The graph comes out great ...  2018-01-01 00:00:44             NaN  9116172.0
# 3    83064113  48045799      0  why do you convert fetchall into `str()` ? Wit...  2018-01-01 00:00:59             NaN  1832058.0
# 4    83064114  48038560      0  This sounds like above my skill level. Maybe a...  2018-01-01 00:01:04             NaN   930993.0
# 5    83064116  48046178      0  Use `ConvertTo-Csv` and replace 3 consecutive ...  2018-01-01 00:01:30             NaN  1630171.0
# ...

# %%
relA2_df.describe(include='all')
# Out:
#                   Id        PostId       Score  \
# count   9.880000e+02  9.880000e+02  988.000000
# unique           NaN           NaN         NaN
# top              NaN           NaN         NaN
# freq             NaN           NaN         NaN
# mean    8.306486e+07  4.596131e+07    0.244939
# std     4.347223e+02  7.866254e+06    0.717931
# min     8.306411e+07  1.120250e+05    0.000000
# 25%     8.306450e+07  4.804081e+07    0.000000
# 50%     8.306485e+07  4.804639e+07    0.000000
# 75%     8.306525e+07  4.804662e+07    0.000000
# max     8.306561e+07  4.804699e+07    8.000000
#
#                                                      Text  \
# count                                                 988
# unique                                                978
# top     Stack Overflow is a site for programming and d...
# freq                                                    8
# mean                                                  NaN
# ...

# %% [markdown]
# ### Posts

# %%
relA3_df = pd.read_csv("../releases/jan-01-02_2018/POSTS_jan-01-02_2018.csv")
print(relA3_df.to_string())
# Out:
#           Id  PostTypeId  AcceptedAnswerId    ParentId         CreationDate         DeletionDate  Score  ViewCount                                               Body  OwnerUserId OwnerDisplayName  LastEditorUserId  LastEditorDisplayName         LastEditDate     LastActivityDate                                              Title                                               Tags  AnswerCount  CommentCount  FavoriteCount  ClosedDate  CommunityOwnedDate
# 0   48046378         1.0               NaN         NaN  2018-01-01 00:00:29                  NaN    0.0      112.0  <p>Calling a <em>dll</em> from Python using <e...    8276973.0              NaN          236247.0                    NaN  2018-01-01 03:16:54  2018-01-03 08:21:23    Python ctypes: how to pass ctypes array to DLL?                                   <python><ctypes>          2.0           0.0            NaN         NaN                 NaN
# ...

# %%
relA3_df.describe(include='all')
# Out:
#               Id  PostTypeId  AcceptedAnswerId      ParentId  \
# count         47   46.000000      8.000000e+00  2.500000e+01
# unique        47         NaN               NaN           NaN
# top     48046378         NaN               NaN           NaN
# freq           1         NaN               NaN           NaN
# mean         NaN    1.543478      4.807512e+07  4.803257e+07
# std          NaN    0.503610      7.955717e+04  6.425668e+04
# min          NaN    1.000000      4.804643e+07  4.772433e+07
# 25%          NaN    1.000000      4.804646e+07  4.804614e+07
# 50%          NaN    2.000000      4.804653e+07  4.804634e+07
# 75%          NaN    2.000000      4.804765e+07  4.804636e+07
# max          NaN    2.000000      4.827200e+07  4.804642e+07
#
#                CreationDate         DeletionDate      Score    ViewCount  \
# count                    46                    1  46.000000    21.000000
# unique                   46                    1        NaN          NaN
# ...

# %% [markdown]
# ### Users

# %%
relA4_df = pd.read_csv("../releases/jan-01-02_2018/USERS_jan-01-02_2018.csv")
print(relA4_df.to_string())
# Out:
#           Id  Reputation         CreationDate                    DisplayName       LastAccessDate                                         WebsiteUrl                                           Location                                            AboutMe  Views  UpVotes  DownVotes                                    ProfileImageUrl  EmailHash  AccountId
# 0    9159469           1  2018-01-01 00:00:47                            wil  2018-03-30 22:12:13                                                NaN                                                NaN                                                NaN      0        0          0  https://www.gravatar.com/avatar/5f1d775e49b29f...        NaN   12594064
# ...

# %%
relA4_df.describe(include='all')
# Out:
#                   Id  Reputation         CreationDate DisplayName  \
# count   9.210000e+02  921.000000                  921         921
# unique           NaN         NaN                  910         920
# top              NaN         NaN  2018-01-01 05:06:37      Andrew
# freq             NaN         NaN                    2           2
# mean    9.160065e+06    3.804560                  NaN         NaN
# std     4.081911e+02   14.692087                  NaN         NaN
# min     9.159469e+06    1.000000                  NaN         NaN
# 25%     9.159708e+06    1.000000                  NaN         NaN
# 50%     9.160087e+06    1.000000                  NaN         NaN
# 75%     9.160325e+06    1.000000                  NaN         NaN
# max     9.161005e+06  178.000000                  NaN         NaN
#
#              LastAccessDate              WebsiteUrl Location  \
# count                   921                      27      346
# ...

# %% [markdown]
# ### Votes

# %%
relA5_df = pd.read_csv("../releases/jan-01-02_2018/VOTES_jan-01-02_2018.csv")
print(relA5_df.to_string())
# Out:
#              Id    PostId  VoteTypeId     UserId         CreationDate  BountyAmount
# 0     154211782  48046304           3        NaN  2018-01-01 00:00:00           NaN
# 1     154211783  48046293           2        NaN  2018-01-01 00:00:00           NaN
# 2     154211785  48046339           2        NaN  2018-01-01 00:00:00           NaN
# 3     154211787  12934468           2        NaN  2018-01-01 00:00:00           NaN
# 4     154211788   4088524           2        NaN  2018-01-01 00:00:00           NaN
# 5     154211789  48046371          10        NaN  2018-01-01 00:00:00           NaN
# 6     154211790  48046318           2        NaN  2018-01-01 00:00:00           NaN
# 7     154211791  48046334          10        NaN  2018-01-01 00:00:00           NaN
# 8     154211792  36507481           2        NaN  2018-01-01 00:00:00           NaN
# 9     154211793  48044734          16        NaN  2018-01-01 00:00:00           NaN
# ...

# %%
relA5_df.describe(include='all')
# Out:
#                   Id        PostId   VoteTypeId        UserId  \
# count   1.023000e+03  1.023000e+03  1023.000000  7.400000e+01
# unique           NaN           NaN          NaN           NaN
# top              NaN           NaN          NaN           NaN
# freq             NaN           NaN          NaN           NaN
# mean    1.542123e+08  3.300841e+07     3.020528  5.058675e+06
# std     3.206166e+02  1.763383e+07     2.632510  3.272631e+06
# min     1.542118e+08  1.540000e+02     1.000000  4.485200e+04
# 25%     1.542121e+08  1.526348e+07     2.000000  1.984560e+06
# 50%     1.542123e+08  4.402906e+07     2.000000  4.789452e+06
# 75%     1.542126e+08  4.804588e+07     3.000000  8.754545e+06
# max     1.542129e+08  4.804661e+07    16.000000  9.159420e+06
#
#                CreationDate  BountyAmount
# count                  1023           0.0
# unique                    1           NaN
# top     2018-01-01 00:00:00           NaN
# freq                   1023           NaN
# ...

# %% [markdown]
# ## January 2nd 2018
# ### Badges

# %%
relB1_df = pd.read_csv("../releases/jan-02-03_2018/BADGES_jan-02-03_2018.csv")
print(relB1_df.to_string())
# Out:
#             Id   UserId               Name                 Date  Class  TagBased
# 0     26418911  2235158            Fanatic  2018-01-02 05:52:21      1     False
# 1     26418912  3478385   Popular Question  2018-01-02 05:52:21      3     False
# 2     26418913  3739821   Popular Question  2018-01-02 05:52:21      3     False
# 3     26418914  1017466   Popular Question  2018-01-02 05:52:21      3     False
# 4     26418915  6198279   Popular Question  2018-01-02 05:52:21      3     False
# 5     26418916  9116354            Scholar  2018-01-02 05:52:21      3     False
# 6     26418917  8481550            Scholar  2018-01-02 05:52:21      3     False
# 7     26418918  7296078            Scholar  2018-01-02 05:52:21      3     False
# 8     26418919  9125472          Custodian  2018-01-02 05:52:21      3     False
# 9     26418920  9162470           Informed  2018-01-02 05:54:12      3     False
# 10    26418921  9162423           Informed  2018-01-02 05:54:19      3     False
# ...

# %%
relB1_df.describe(include='all')
# Out:
#                   Id        UserId              Name                 Date  \
# count   1.080000e+03  1.080000e+03              1080                 1080
# unique           NaN           NaN                48                  181
# top              NaN           NaN  Popular Question  2018-01-02 07:44:11
# freq             NaN           NaN               152                   50
# mean    2.641946e+07  5.253555e+06               NaN                  NaN
# std     3.164447e+02  3.265226e+06               NaN                  NaN
# min     2.641891e+07  1.156000e+03               NaN                  NaN
# 25%     2.641918e+07  2.037564e+06               NaN                  NaN
# 50%     2.641946e+07  5.514526e+06               NaN                  NaN
# 75%     2.641973e+07  8.700154e+06               NaN                  NaN
# max     2.642000e+07  9.162973e+06               NaN                  NaN
#
#               Class TagBased
# count   1080.000000     1080
# ...

# %% [markdown]
# ### Comments

# %%
relB2_df = pd.read_csv("../releases/jan-02-03_2018/COMMENTS_jan-02-03_2018.csv")
print(relB2_df.to_string())
# Out:
#            Id    PostId  Score                                               Text         CreationDate UserDisplayName     UserId
# 0    83080788  48054195      0  ahh, I know why, I need to use recursive setti...  2018-01-02 00:00:02             NaN  5047085.0
# 1    83080789  48053955      1  `target_metadata` should just be `target_metad...  2018-01-02 00:00:06             NaN   341730.0
# 2    83080790  48053966      0  @IoannaDln: How exactly are you determining th...  2018-01-02 00:00:13             NaN   115145.0
# 3    83080792  48045608      0  The vertical and perpendicular distances achie...  2018-01-02 00:00:16             NaN  3580870.0
# 4    83080794  48051286      0  The only way you'll get to the bottom of your ...  2018-01-02 00:00:40             NaN  3426025.0
# 5    83080795  48054069      0  @PesaThe I don't know how I could be more clea...  2018-01-02 00:00:44             NaN  6317562.0
# ...

# %%
relB2_df.describe(include='all')
# Out:
#                   Id        PostId       Score  \
# count   8.880000e+02  8.880000e+02  888.000000
# unique           NaN           NaN         NaN
# top              NaN           NaN         NaN
# freq             NaN           NaN         NaN
# mean    8.308229e+07  4.620468e+07    0.210586
# std     1.074315e+03  7.088214e+06    0.647274
# min     8.308079e+07  4.662420e+05    0.000000
# 25%     8.308114e+07  4.804663e+07    0.000000
# 50%     8.308191e+07  4.805419e+07    0.000000
# 75%     8.308334e+07  4.805494e+07    0.000000
# max     8.308396e+07  4.805586e+07    8.000000
#
#                                                      Text  \
# count                                                 888
# unique                                                886
# top     FYI, the [Joda-Time](http://www.joda.org/joda-...
# freq                                                    2
# mean                                                  NaN
# ...

# %% [markdown]
# ### Posts

# %%
relB3_df = pd.read_csv("../releases/jan-02-03_2018/POSTS_jan-02-03_2018.csv")
print(relB3_df.to_string())
# Out:
#           Id  PostTypeId  AcceptedAnswerId    ParentId         CreationDate  DeletionDate  Score  ViewCount                                               Body  OwnerUserId  OwnerDisplayName  LastEditorUserId LastEditorDisplayName         LastEditDate     LastActivityDate                                              Title                                               Tags  AnswerCount  CommentCount  FavoriteCount           ClosedDate  CommunityOwnedDate
# 0   48155065           1        48155066.0         NaN  2018-01-02 11:57:23           NaN      1      160.0  <p>I'm trying to update a Google Sheets add-on...       246754  Anonymouslemming               NaN                   NaN                  NaN  2018-01-08 17:21:17  How to add dependencies for Google Docs add-on...                                    <google-sheets>          1.0             0            NaN                  NaN                 NaN
# ...

# %%
relB3_df.describe(include='all')
# Out:
#                   Id  PostTypeId  AcceptedAnswerId      ParentId  \
# count   7.100000e+01   71.000000      1.300000e+01  4.400000e+01
# unique           NaN         NaN               NaN           NaN
# top              NaN         NaN               NaN           NaN
# freq             NaN         NaN               NaN           NaN
# mean    4.805578e+07    1.619718      4.807252e+07  4.167991e+07
# std     1.195152e+04    0.488911      3.613892e+04  1.429749e+07
# min     4.805425e+07    1.000000      4.805428e+07  4.663450e+05
# 25%     4.805428e+07    1.000000      4.805448e+07  4.720084e+07
# 50%     4.805430e+07    2.000000      4.805505e+07  4.805348e+07
# 75%     4.805444e+07    2.000000      4.805917e+07  4.805424e+07
# max     4.815506e+07    2.000000      4.815507e+07  4.805453e+07
#
#                CreationDate  DeletionDate      Score    ViewCount  \
# count                    71           0.0  71.000000    27.000000
# ...

# %% [markdown]
# ### Users

# %%
relB4_df = pd.read_csv("../releases/jan-02-03_2018/USERS_jan-02-03_2018.csv")
print(relB4_df.to_string())
# Out:
#           Id  Reputation         CreationDate                    DisplayName       LastAccessDate                                 WebsiteUrl                                           Location                                            AboutMe  Views  UpVotes  DownVotes                                    ProfileImageUrl  EmailHash  AccountId
# 0    9161856           1  2018-01-02 00:01:27                            jim  2018-05-16 19:19:51                                        NaN                                                NaN                                                NaN      1        0          0  https://www.gravatar.com/avatar/d915002de644a9...        NaN   12598091
# ...

# %%
relB4_df.describe(include='all')
# Out:
#                   Id  Reputation         CreationDate DisplayName  \
# count   9.150000e+02  915.000000                  915         915
# unique           NaN         NaN                  892         911
# top              NaN         NaN  2018-01-02 14:54:16       Jason
# freq             NaN         NaN                    2           2
# mean    9.162781e+06    3.786885                  NaN         NaN
# std     9.083733e+02   15.901896                  NaN         NaN
# min     9.161856e+06    1.000000                  NaN         NaN
# 25%     9.162094e+06    1.000000                  NaN         NaN
# 50%     9.162574e+06    1.000000                  NaN         NaN
# 75%     9.162812e+06    1.000000                  NaN         NaN
# max     9.165237e+06  309.000000                  NaN         NaN
#
#              LastAccessDate                                 WebsiteUrl  \
# count                   915                                         24
# ...

# %% [markdown]
# ### Votes

# %%
relB5_df = pd.read_csv("../releases/jan-02-03_2018/VOTES_jan-02-03_2018.csv")
print(relB5_df.to_string())
# Out:
#              Id    PostId  VoteTypeId     UserId         CreationDate  BountyAmount
# 0     154243649  48054252           1        NaN  2018-01-02 00:00:00           NaN
# 1     154243650  48052253           2        NaN  2018-01-02 00:00:00           NaN
# 2     154243651  14472089           2        NaN  2018-01-02 00:00:00           NaN
# 3     154243652  10418669           2        NaN  2018-01-02 00:00:00           NaN
# 4     154243653  12415626           2        NaN  2018-01-02 00:00:00           NaN
# 5     154243654  16607408           2        NaN  2018-01-02 00:00:00           NaN
# 6     154243655  30300521           2        NaN  2018-01-02 00:00:00           NaN
# 7     154243656  39327148           2        NaN  2018-01-02 00:00:00           NaN
# 8     154243657  39327197           2        NaN  2018-01-02 00:00:00           NaN
# 9     154243658   6890120           2        NaN  2018-01-02 00:00:00           NaN
# ...

# %%
relB5_df.describe(include='all')
# Out:
#                   Id        PostId   VoteTypeId        UserId  \
# count   1.024000e+03  1.024000e+03  1024.000000  6.900000e+01
# unique           NaN           NaN          NaN           NaN
# top              NaN           NaN          NaN           NaN
# freq             NaN           NaN          NaN           NaN
# mean    1.542442e+08  3.119017e+07     3.207031  4.044871e+06
# std     3.094786e+02  1.763359e+07     3.175559  3.374804e+06
# min     1.542436e+08  1.711000e+03     1.000000  3.501000e+03
# 25%     1.542439e+08  1.389383e+07     2.000000  7.528430e+05
# 50%     1.542442e+08  3.794794e+07     2.000000  3.566970e+06
# 75%     1.542445e+08  4.804892e+07     3.000000  7.141930e+06
# max     1.542447e+08  4.805445e+07    16.000000  9.159641e+06
#
#                CreationDate  BountyAmount
# count                  1024           0.0
# unique                    1           NaN
# top     2018-01-02 00:00:00           NaN
# freq                   1024           NaN
# ...

# %% [markdown]
# ## January 3rd 2018
# ### Badges

# %%
relC1_df = pd.read_csv("../releases/jan-03-04_2018/BADGES_jan-03-04_2018.csv")
print(relC1_df.to_string())
# Out:
#             Id   UserId               Name                 Date  Class  TagBased
# 0     26431616   324584        Good Answer  2018-01-03 10:21:51      2     False
# 1     26431617  1529630        Good Answer  2018-01-03 10:21:51      2     False
# 2     26431618      893       Great Answer  2018-01-03 10:21:51      1     False
# 3     26431619   919426       Great Answer  2018-01-03 10:21:51      1     False
# 4     26431620  1462775       Great Answer  2018-01-03 10:21:51      1     False
# 5     26431621   203130      Nice Question  2018-01-03 10:21:51      3     False
# 6     26431622   133212     Great Question  2018-01-03 10:21:51      1     False
# 7     26431623  8270735     Autobiographer  2018-01-03 10:21:51      3     False
# 8     26431624  5070121     Autobiographer  2018-01-03 10:21:51      3     False
# 9     26431625  5877490     Citizen Patrol  2018-01-03 10:18:47      3     False
# 10    26431626  6857863        Commentator  2018-01-03 10:21:51      3     False
# ...

# %%
relC1_df.describe(include='all')
# Out:
#                   Id        UserId              Name                 Date  \
# count   1.188000e+03  1.188000e+03              1188                 1188
# unique           NaN           NaN                48                  172
# top              NaN           NaN  Popular Question  2018-01-03 10:49:26
# freq             NaN           NaN               131                   72
# mean    2.642948e+07  5.152138e+06               NaN                  NaN
# std     1.863393e+03  3.311401e+06               NaN                  NaN
# min     2.642750e+07  8.930000e+02               NaN                  NaN
# 25%     2.642781e+07  1.933697e+06               NaN                  NaN
# 50%     2.642850e+07  5.174641e+06               NaN                  NaN
# 75%     2.643177e+07  8.822058e+06               NaN                  NaN
# max     2.643207e+07  9.167763e+06               NaN                  NaN
#
#               Class TagBased
# count   1188.000000     1188
# ...

# %% [markdown]
# ### Comments

# %%
relC2_df = pd.read_csv("../releases/jan-03-04_2018/COMMENTS_jan-03-04_2018.csv")
print(relC2_df.to_string())
# Out:
#            Id    PostId  Score                                               Text         CreationDate UserDisplayName     UserId
# 0    83112682  48066440      0  Can you check something first? Can you take a ...  2018-01-03 00:00:11             NaN  6095508.0
# 1    83112683  48068478      0  U'r right! Ok thx a lot, this works. However a...  2018-01-03 00:00:19             NaN  3106924.0
# 2    83112684  48069455      1  The while loop will run forever, so I would im...  2018-01-03 00:00:22             NaN  6864876.0
# 3    83112685  48069125      1  Ah, yes. I didn't see that. I just hate seeing...  2018-01-03 00:00:27             NaN  1271826.0
# 4    83112686  48069444      0  no, it is not. The project is a .NET Core 1.1 ...  2018-01-03 00:00:30             NaN  2581562.0
# 5    83112687  48069312      0  Use `overflow-y: scroll;` instead. `auto` seem...  2018-01-03 00:00:34             NaN  3744304.0
# ...

# %%
relC2_df.describe(include='all')
# Out:
#                   Id        PostId       Score  \
# count   9.940000e+02  9.940000e+02  994.000000
# unique           NaN           NaN         NaN
# top              NaN           NaN         NaN
# freq             NaN           NaN         NaN
# mean    8.311472e+07  4.641149e+07    0.203219
# std     2.212448e+03  6.651071e+06    0.579048
# min     8.311268e+07  1.069634e+06    0.000000
# 25%     8.311303e+07  4.805801e+07    0.000000
# 50%     8.311342e+07  4.806935e+07    0.000000
# 75%     8.311747e+07  4.806979e+07    0.000000
# max     8.311858e+07  4.807249e+07    6.000000
#
#                                                      Text  \
# count                                                 994
# unique                                                992
# top     Now I've added one more field in the yaml file...
# freq                                                    2
# mean                                                  NaN
# ...

# %% [markdown]
# ### Posts

# %%
relC3_df = pd.read_csv("../releases/jan-03-04_2018/POSTS_jan-03-04_2018.csv")
print(relC3_df.to_string())
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-62-db2ce7004885> in <module>
# ----> 1 relC3_df = pd.read_csv("../releases/jan-03-04_2018/POSTS_jan-03-04_2018.csv")
#       2 print(relC3_df.to_string())
#
# ...

# %%
relC3_df.describe(include='all')

# %% [markdown]
# ### Users

# %%
relC4_df = pd.read_csv("../releases/jan-03-04_2018/USERS_jan-03-04_2018.csv")
print(relC4_df.to_string())

# %%
relC4_df.describe(include='all')

# %% [markdown]
# ### Votes

# %%
relC5_df = pd.read_csv("../releases/jan-03-04_2018/VOTES_jan-03-04_2018.csv")
print(relC5_df.to_string())

# %%
relC5_df.describe(include='all')
